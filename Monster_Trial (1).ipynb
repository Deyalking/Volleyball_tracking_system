# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17485, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 17485 (delta 79), reused 30 (delta 30), pack-reused 17378 (from 3)
# Receiving objects: 100% (17485/17485), 16.35 MiB | 10.34 MiB/s, done.
# Resolving deltas: 100% (11990/11990), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24db1193-3d68-488b-9235-2feb76a4ea08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24db1193-3d68-488b-9235-2feb76a4ea08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /'content/yolov5'
# Out:
# benchmarks.py	 data	     LICENSE	     README.zh-CN.md   tutorial.ipynb
# CITATION.cff	 detect.py   models	     requirements.txt  utils
# classify	 export.py   pyproject.toml  segment	       val.py
# CONTRIBUTING.md  hubconf.py  README.md	     train.py

# %%
# %cd /content
# !unzip /'content/yolov5/Custom Workflow Object Detection.v7i.yolov5pytorch.zip' -d /content/volleyball_dataset
# Out:
# /content
# unzip:  cannot find or open /content/yolov5/Custom Workflow Object Detection.v7i.yolov5pytorch.zip, /content/yolov5/Custom Workflow Object Detection.v7i.yolov5pytorch.zip.zip or /content/yolov5/Custom Workflow Object Detection.v7i.yolov5pytorch.zip.ZIP.

# %%
# !ls /content/volleyball_dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train

# %%
# !cp -r /content/volleyball_dataset/train /content/volleyball_dataset/val

# %%
# !ls /content/volleyball_dataset/train/images | head
# !ls /content/volleyball_dataset/val/images | head
# Out:
# clip_four_mp4-0002_jpg.rf.c28b96780843ea36f464d7bd1a23a693.jpg
# clip_four_mp4-0005_jpg.rf.2ec031ae03315a564752f6fe874f65d5.jpg
# clip_four_mp4-0006_jpg.rf.f4e8b98e5f29699ea3119e4625dd8ed6.jpg
# clip_four_mp4-0009_jpg.rf.5e14c8550bcae3b8c8f75357f9bd81e2.jpg
# clip_four_mp4-0010_jpg.rf.8c54f9cc1afb1951948158129f1078a0.jpg
# clip_four_mp4-0011_jpg.rf.1a19fad692c9b74fa28c7ff855f61af9.jpg
# clip_four_mp4-0012_jpg.rf.afb9e7aefc03a0b88c0cc0326b37278d.jpg
# clip_four_mp4-0014_jpg.rf.06f37d8b01dfb1b7af111bc34c254290.jpg
# clip_four_mp4-0015_jpg.rf.3060fc58ba70faa30986a049582f6760.jpg
# clip_four_mp4-0016_jpg.rf.423b5698036bbd64addfd10bf394446d.jpg
# clip_four_mp4-0002_jpg.rf.c28b96780843ea36f464d7bd1a23a693.jpg
# clip_four_mp4-0005_jpg.rf.2ec031ae03315a564752f6fe874f65d5.jpg
# clip_four_mp4-0006_jpg.rf.f4e8b98e5f29699ea3119e4625dd8ed6.jpg
# clip_four_mp4-0009_jpg.rf.5e14c8550bcae3b8c8f75357f9bd81e2.jpg
# clip_four_mp4-0010_jpg.rf.8c54f9cc1afb1951948158129f1078a0.jpg
# ...

# %%
yaml_content = """
train: /content/volleyball_dataset/train/images
val: /content/volleyball_dataset/val/images

nc: 8
names: ['Ball', 'Block_players', 'Libero', 'Manager', 'Passer', 'Player', 'Setter', 'Spike_Player']
"""

with open('/content/volleyball_dataset/data.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !cat /content/volleyball_dataset/data.yaml
# Out:
# train: /content/volleyball_dataset/train/images
# val: /content/volleyball_dataset/val/images
#
# nc: 8
# names: ['Ball', 'Block_players', 'Libero', 'Manager', 'Passer', 'Player', 'Setter', 'Spike_Player']

# %%
# !python3 /content/yolov5/train.py --img 640 --batch 16 --epochs 30 --data /content/volleyball_dataset/data.yaml --weights yolov5s.pt --cache
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-04-15 15:51:05.783716: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744732266.179512    3418 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b5659542-a538-45dd-a624-2e9b0fab7abd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5659542-a538-45dd-a624-2e9b0fab7abd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python /content/yolov5/detect.py \
  --weights /content/yolov5/runs/train/exp3/weights/best.pt \
  --img 640 \
  --conf 0.25 \
  --source /content/clip_four_mp4-0086_jpg.rf.4419f5a6c6341b138140ac5f2829b812.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/clip_four_mp4-0086_jpg.rf.4419f5a6c6341b138140ac5f2829b812.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/clip_four_mp4-0086_jpg.rf.4419f5a6c6341b138140ac5f2829b812.jpg: 640x640 11 Players, 487.3ms
# Speed: 5.0ms pre-process, 487.3ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# !ls /content/clip_four_mp4-0086_jpg.rf.4419f5a6c6341b138140ac5f2829b812.jpg
# Out:
# /content/clip_four_mp4-0086_jpg.rf.4419f5a6c6341b138140ac5f2829b812.jpg

# %%
from IPython.display import Image
Image(filename='/content/yolov5/runs/detect/exp4/clip_four_mp4-0086_jpg.rf.4419f5a6c6341b138140ac5f2829b812.jpg')

# %%
--source /path/to/
